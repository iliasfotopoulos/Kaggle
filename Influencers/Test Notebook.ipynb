# %%
import pandas as pd
import numpy as np
import pylab as pl

# %%
df = pd.read_csv("data/train.csv")

# %%
df.header()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-6892501c8ed3> in <module>()
# ----> 1 df.header()
#
# /home/ilias/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    1945                 return self[name]
#    1946             raise AttributeError("'%s' object has no attribute '%s'" %
# -> 1947                                  (type(self).__name__, name))
#    1948
#    1949     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'header'

# %%
df.head()
# Out:
#    Choice  A_follower_count  A_following_count  A_listed_count  \
# 0       0               228                302               3
# 1       0             21591               1179             228
# 2       0              7310               1215             101
# 3       0                20                  7               2
# 4       1             45589                862            2641
#
#    A_mentions_received  A_retweets_received  A_mentions_sent  A_retweets_sent  \
# 0             0.583979             0.100503         0.100503         0.100503
# 1            90.456506            25.798292         5.709329         1.111159
# 2            25.503644             9.556347         5.361519         0.591206
# 3             7.690824             0.277306         1.331508         0.100503
# 4           148.854279            36.998884        27.881768         3.333492
#
#      A_posts  A_network_feature_1         ...           B_following_count  \
# ...

# %%
A_features = [float(item) for item in splitted[1:12]]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-90b12fa6ef34> in <module>()
# ----> 1 A_features = [float(item) for item in splitted[1:12]]
#
# NameError: name 'splitted' is not defined

# %%
df[1:12]
# Out:
#     Choice  A_follower_count  A_following_count  A_listed_count  \
# 1        0             21591               1179             228
# 2        0              7310               1215             101
# 3        0                20                  7               2
# 4        1             45589                862            2641
# 5        0            285735             276251            3417
# 6        0            285735             276251            3417
# 7        1              9512                 12             213
# 8        1           2273871               4524           11946
# 9        0            182598               1402            3831
# 10       0              3200               3256             146
# 11       0              3914               1439             165
#
#     A_mentions_received  A_retweets_received  A_mentions_sent  \
# 1             90.456506            25.798292         5.709329
# 2             25.503644             9.556347         5.361519
# ...

# %%
df[:,:12]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-d86f406024df> in <module>()
# ----> 1 df[:,:12]
#
# /home/ilias/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1778             return self._getitem_multilevel(key)
#    1779         else:
# -> 1780             return self._getitem_column(key)
#    1781
#    1782     def _getitem_column(self, key):
#
# /home/ilias/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    1785         # get column
#    1786         if self.columns.is_unique:
# -> 1787             return self._get_item_cache(key)
#    1788
#    1789         # duplicate columns & possible reduce dimensionaility
#
# /home/ilias/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
# ...

# %%
df[:,1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-ff65926f441e> in <module>()
# ----> 1 df[:,1]
#
# /home/ilias/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1778             return self._getitem_multilevel(key)
#    1779         else:
# -> 1780             return self._getitem_column(key)
#    1781
#    1782     def _getitem_column(self, key):
#
# /home/ilias/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    1785         # get column
#    1786         if self.columns.is_unique:
# -> 1787             return self._get_item_cache(key)
#    1788
#    1789         # duplicate columns & possible reduce dimensionaility
#
# /home/ilias/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
# ...

# %%
df[:2]
# Out:
#    Choice  A_follower_count  A_following_count  A_listed_count  \
# 0       0               228                302               3
# 1       0             21591               1179             228
#
#    A_mentions_received  A_retweets_received  A_mentions_sent  A_retweets_sent  \
# 0             0.583979             0.100503         0.100503         0.100503
# 1            90.456506            25.798292         5.709329         1.111159
#
#    A_posts  A_network_feature_1         ...           B_following_count  \
# 0  0.36215                    2         ...                       29808
# 1  5.17662                  369         ...                         848
#
#    B_listed_count  B_mentions_received  B_retweets_received  B_mentions_sent  \
# 0            1689            15.430498             3.984029         8.204331
# 1            1610            40.495021             8.943607         3.227677
#
#    B_retweets_sent   B_posts  B_network_feature_1  B_network_feature_2  \
# ...

# %%
df[:][12]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-47ccfa2462ca> in <module>()
# ----> 1 df[:][12]
#
# /home/ilias/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1778             return self._getitem_multilevel(key)
#    1779         else:
# -> 1780             return self._getitem_column(key)
#    1781
#    1782     def _getitem_column(self, key):
#
# /home/ilias/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    1785         # get column
#    1786         if self.columns.is_unique:
# -> 1787             return self._get_item_cache(key)
#    1788
#    1789         # duplicate columns & possible reduce dimensionaility
#
# /home/ilias/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1066         res = cache.get(item)
# ...

# %%
y = df[['choice']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-459119689909> in <module>()
# ----> 1 y = df[['choice']]
#
# /home/ilias/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1772         if isinstance(key, (Series, np.ndarray, Index, list)):
#    1773             # either boolean or fancy integer index
# -> 1774             return self._getitem_array(key)
#    1775         elif isinstance(key, DataFrame):
#    1776             return self._getitem_frame(key)
#
# /home/ilias/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_array(self, key)
#    1816             return self.take(indexer, axis=0, convert=False)
#    1817         else:
# -> 1818             indexer = self.ix._convert_to_indexer(key, axis=1)
#    1819             return self.take(indexer, axis=1, convert=True)
#    1820
#
# ...

# %%
y = df[['Choice']]

# %%
y
# Out:
#       Choice
# 0          0
# 1          0
# 2          0
# 3          0
# 4          1
# 5          0
# 6          0
# 7          1
# 8          1
# 9          0
# 10         0
# 11         0
# 12         1
# 13         0
# 14         1
# 15         1
# 16         0
# 17         0
# 18         1
# 19         1
# 20         0
# 21         1
# 22         1
# 23         0
# 24         0
# 25         0
# 26         0
# 27         1
# 28         1
# 29         0
# ...      ...
# 5470       0
# 5471       0
# 5472       0
# 5473       0
# 5474       1
# 5475       0
# 5476       0
# 5477       1
# 5478       1
# 5479       1
# 5480       0
# 5481       1
# 5482       0
# 5483       1
# 5484       1
# 5485       1
# 5486       0
# 5487       1
# 5488       1
# 5489       0
# 5490       1
# 5491       0
# 5492       0
# 5493       0
# 5494       1
# 5495       0
# 5496       1
# 5497       0
# 5498       0
# 5499       0
#
# [5500 rows x 1 columns]

# %%
df
# Out:
#       Choice  A_follower_count  A_following_count  A_listed_count  \
# 0          0               228                302               3
# 1          0             21591               1179             228
# 2          0              7310               1215             101
# 3          0                20                  7               2
# 4          1             45589                862            2641
# 5          0            285735             276251            3417
# 6          0            285735             276251            3417
# 7          1              9512                 12             213
# 8          1           2273871               4524           11946
# 9          0            182598               1402            3831
# 10         0              3200               3256             146
# 11         0              3914               1439             165
# 12         1             23230                495             826
# ...

# %%
df.head()
# Out:
#    Choice  A_follower_count  A_following_count  A_listed_count  \
# 0       0               228                302               3
# 1       0             21591               1179             228
# 2       0              7310               1215             101
# 3       0                20                  7               2
# 4       1             45589                862            2641
#
#    A_mentions_received  A_retweets_received  A_mentions_sent  A_retweets_sent  \
# 0             0.583979             0.100503         0.100503         0.100503
# 1            90.456506            25.798292         5.709329         1.111159
# 2            25.503644             9.556347         5.361519         0.591206
# 3             7.690824             0.277306         1.331508         0.100503
# 4           148.854279            36.998884        27.881768         3.333492
#
#      A_posts  A_network_feature_1         ...           B_following_count  \
# ...

# %%
df.loc[:,:12]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-905670f75374> in <module>()
# ----> 1 df.loc[:,:12]
#
# /home/ilias/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in __getitem__(self, key)
#    1198     def __getitem__(self, key):
#    1199         if type(key) is tuple:
# -> 1200             return self._getitem_tuple(key)
#    1201         else:
#    1202             return self._getitem_axis(key, axis=0)
#
# /home/ilias/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_tuple(self, tup)
#     702
#     703         # no multi-index, so validate all of the indexers
# --> 704         self._has_valid_tuple(tup)
#     705
#     706         # ugly hack for GH #836
#
# /home/ilias/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in _has_valid_tuple(self, key)
#     129             if i >= self.obj.ndim:
# ...

# %%
df[::12]
# Out:
#       Choice  A_follower_count  A_following_count  A_listed_count  \
# 0          0               228                302               3
# 12         1             23230                495             826
# 24         0             26821              24787             144
# 36         0              5039               1159              97
# 48         0           1209835                  3           12226
# 60         0               671                215              17
# 72         1           8168488                 76           25928
# 84         1             67736              30523            1948
# 96         1            486540             260467            6755
# 108        1            126738                779            4115
# 120        1              7147                737             112
# 132        0              2696               1718              20
# 144        0             28613               3557               9
# ...

# %%
df[::2]
# Out:
#       Choice  A_follower_count  A_following_count  A_listed_count  \
# 0          0               228                302               3
# 2          0              7310               1215             101
# 4          1             45589                862            2641
# 6          0            285735             276251            3417
# 8          1           2273871               4524           11946
# 10         0              3200               3256             146
# 12         1             23230                495             826
# 14         1              2088                419             148
# 16         0              4760                425              96
# 18         1            265258                209             551
# 20         0            352126                499            4428
# 22         1            356712               2070            2804
# 24         0             26821              24787             144
# ...

# %%
df.ix[:,0:2]
# Out:
#       Choice  A_follower_count
# 0          0               228
# 1          0             21591
# 2          0              7310
# 3          0                20
# 4          1             45589
# 5          0            285735
# 6          0            285735
# 7          1              9512
# 8          1           2273871
# 9          0            182598
# 10         0              3200
# 11         0              3914
# 12         1             23230
# 13         0           4321482
# 14         1              2088
# 15         1             48711
# 16         0              4760
# 17         0             15385
# 18         1            265258
# 19         1            723800
# 20         0            352126
# 21         1           4947410
# 22         1            356712
# 23         0               127
# 24         0             26821
# 25         0             41367
# 26         0           2774790
# 27         1             98788
# 28         1             57840
# ...

# %%
import load_data2

# %%
load_data2.load("train")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-07fcfd4c625f> in <module>()
# ----> 1 load_data2.load("train")
#
# /home/ilias/Kaggle/Influencers/load_data2.py in load(type)
#      25         X_B = data.ix[:,r_limit:]
#      26
# ---> 27         filee.close()
#      28
#      29         #Return panda files
#
# NameError: global name 'filee' is not defined

# %%
load_data2.load("train")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-07fcfd4c625f> in <module>()
# ----> 1 load_data2.load("train")
#
# /home/ilias/Kaggle/Influencers/load_data2.py in load(type)
#      25         X_B = data.ix[:,r_limit:]
#      26
# ---> 27         data.close()
#      28
#      29         #Return panda files
#
# NameError: global name 'filee' is not defined

# %%
load_data2.load("train")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-07fcfd4c625f> in <module>()
# ----> 1 load_data2.load("train")
#
# /home/ilias/Kaggle/Influencers/load_data2.py in load(type)
#      25         X_B = data.ix[:,r_limit:]
#      26
# ---> 27         data.close()
#      28
#      29         #Return panda files
#
# NameError: global name 'filee' is not defined

# %%
load_data2.load("train")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-07fcfd4c625f> in <module>()
# ----> 1 load_data2.load("train")
#
# /home/ilias/Kaggle/Influencers/load_data2.py in load(type)
#      25         X_B = data.ix[:,r_limit:]
#      26
# ---> 27         data.close()
#      28
#      29         #Return panda files
#
# NameError: global name 'filee' is not defined

# %%
import load_data2

# %%
load_data2.load("train")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-07fcfd4c625f> in <module>()
# ----> 1 load_data2.load("train")
#
# /home/ilias/Kaggle/Influencers/load_data2.py in load(type)
#      25         X_B = data.ix[:,r_limit:]
#      26
# ---> 27         data.close()
#      28
#      29         #Return panda files
#
# /home/ilias/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    1945                 return self[name]
#    1946             raise AttributeError("'%s' object has no attribute '%s'" %
# -> 1947                                  (type(self).__name__, name))
#    1948
#    1949     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'close'

# %%
import load_data2

# %%
load_data2.load("train")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-07fcfd4c625f> in <module>()
# ----> 1 load_data2.load("train")
#
# /home/ilias/Kaggle/Influencers/load_data2.py in load(type)
#      25         X_B = data.ix[:,r_limit:]
#      26
# ---> 27         #Return panda files
#      28         if type == "train":
#      29                 return X_A, X_B, y
#
# /home/ilias/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    1945                 return self[name]
#    1946             raise AttributeError("'%s' object has no attribute '%s'" %
# -> 1947                                  (type(self).__name__, name))
#    1948
#    1949     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'close'

# %%
import load_data2
load_data2.load("train")
# Out:
# (      A_follower_count  A_following_count  A_listed_count  \
#  0                  228                302               3
#  1                21591               1179             228
#  2                 7310               1215             101
#  3                   20                  7               2
#  4                45589                862            2641
#  5               285735             276251            3417
#  6               285735             276251            3417
#  7                 9512                 12             213
#  8              2273871               4524           11946
#  9               182598               1402            3831
#  10                3200               3256             146
#  11                3914               1439             165
#  12               23230                495             826
#  13             4321482                259           32741
#  14                2088                419             148
# ...

# %%
X_A, X_B, y = load_data2.load("train")

# %%
X_A
# Out:
#       A_follower_count  A_following_count  A_listed_count  \
# 0                  228                302               3
# 1                21591               1179             228
# 2                 7310               1215             101
# 3                   20                  7               2
# 4                45589                862            2641
# 5               285735             276251            3417
# 6               285735             276251            3417
# 7                 9512                 12             213
# 8              2273871               4524           11946
# 9               182598               1402            3831
# 10                3200               3256             146
# 11                3914               1439             165
# 12               23230                495             826
# 13             4321482                259           32741
# 14                2088                419             148
# ...

# %%
X_A(np.log1p)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-d0f593c263ad> in <module>()
# ----> 1 X_A(np.log1p)
#
# NameError: name 'np' is not defined

# %%
import numpy as np

# %%
X_A(np.log1p)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-d0f593c263ad> in <module>()
# ----> 1 X_A(np.log1p)
#
# TypeError: 'DataFrame' object is not callable

# %%
X_A.apply(np.log1p)
# Out:
#       A_follower_count  A_following_count  A_listed_count  \
# 0             5.433722           5.713733        1.386294
# 1             9.980078           7.073270        5.433722
# 2             8.897135           7.103322        4.624973
# 3             3.044522           2.079442        1.098612
# 4            10.727444           6.760415        7.879291
# 5            12.562824          12.529069        8.136811
# 6            12.562824          12.529069        8.136811
# 7             9.160415           2.564949        5.365976
# 8            14.636995           8.417373        9.388235
# 9            12.115048           7.246368        8.251142
# 10            8.071219           8.088562        4.990433
# 11            8.272571           7.272398        5.111988
# 12           10.053243           6.206576        6.717805
# 13           15.279109           5.560682       10.396414
# 14            7.644441           6.040255        5.003946
# ...

# %%
X_A["ratio"] = X_A["A_follower_count"] / X_A["A_following_count"]

# %%
X_A["ration"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-6d3dfbadc2c6> in <module>()
# ----> 1 X_A["ration"]
#
# /home/ilias/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1778             return self._getitem_multilevel(key)
#    1779         else:
# -> 1780             return self._getitem_column(key)
#    1781
#    1782     def _getitem_column(self, key):
#
# /home/ilias/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    1785         # get column
#    1786         if self.columns.is_unique:
# -> 1787             return self._get_item_cache(key)
#    1788
#    1789         # duplicate columns & possible reduce dimensionaility
#
# /home/ilias/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1066         res = cache.get(item)
# ...

# %%
X_A["ratio"]
# Out:
# 0         0.754967
# 1        18.312977
# 2         6.016461
# 3         2.857143
# 4        52.887471
# 5         1.034331
# 6         1.034331
# 7       792.666667
# 8       502.624005
# 9       130.241084
# 10        0.982801
# 11        2.719944
# 12       46.929293
# 13    16685.258687
# 14        4.983294
# ...
# 5485     307.311697
# 5486       1.051168
# 5487       5.996398
# 5488     190.634238
# 5489       3.067358
# 5490    9200.333333
# 5491       1.122029
# 5492       0.556962
# 5493     128.495448
# 5494       1.215025
# 5495     225.756757
# 5496       0.460905
# 5497      22.860327
# 5498    1269.177033
# 5499       0.681868
# Name: ratio, Length: 5500, dtype: float64

# %%
X_A["ratio"] = X_A.ix[:,0] / X_A.ix[:,1]

# %%
X_A["ratio"]
# Out:
# 0         0.754967
# 1        18.312977
# 2         6.016461
# 3         2.857143
# 4        52.887471
# 5         1.034331
# 6         1.034331
# 7       792.666667
# 8       502.624005
# 9       130.241084
# 10        0.982801
# 11        2.719944
# 12       46.929293
# 13    16685.258687
# 14        4.983294
# ...
# 5485     307.311697
# 5486       1.051168
# 5487       5.996398
# 5488     190.634238
# 5489       3.067358
# 5490    9200.333333
# 5491       1.122029
# 5492       0.556962
# 5493     128.495448
# 5494       1.215025
# 5495     225.756757
# 5496       0.460905
# 5497      22.860327
# 5498    1269.177033
# 5499       0.681868
# Name: ratio, Length: 5500, dtype: float64

# %%
from sklearn import linear_model
from sklearn import metrics
from sklearn.ensemble import GradientBoostingClassifier
import numpy as np
import pandas as pd
import load_data2 as load_data
import preprocess2 as pre

# %%
X_train_A, X_train_B, y_train = load_data.load("train")
X_test_A, X_test_B = load_data.load("test")

# %%
X_train = pre.proc(X_train_A) - pre.proc(X_train_B)

# %%
model = linear_model.LogisticRegression(fit_intercept=False)

# %%
model.fit(X_train,y_train
# Out:
#   File "<ipython-input-5-b4a992bc5a55>", line 1
#     model.fit(X_train,y_train
#                              ^
# SyntaxError: unexpected EOF while parsing

# %%
model.fit(X_train,y_train)
# Out:
# /home/ilias/anaconda/lib/python2.7/site-packages/sklearn/preprocessing/label.py:125: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-27c89f04d08a> in <module>()
# ----> 1 model.fit(X_train,y_train)
#
# /home/ilias/anaconda/lib/python2.7/site-packages/sklearn/svm/base.pyc in fit(self, X, y)
#     677                              " one.")
#     678
# --> 679         X = atleast2d_or_csr(X, dtype=np.float64, order="C")
#     680
#     681         self.class_weight_ = compute_class_weight(self.class_weight,
#
# /home/ilias/anaconda/lib/python2.7/site-packages/sklearn/utils/validation.pyc in atleast2d_or_csr(X, dtype, order, copy, force_all_finite)
# ...

# %%
y_train.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-ce9ed4f9385a> in <module>()
# ----> 1 y_train.shape()
#
# TypeError: 'tuple' object is not callable

# %%
y_train.head()
# Out:
#    Choice
# 0       0
# 1       0
# 2       0
# 3       0
# 4       1

# %%
X_train.head()
# Out:
#    A_follower_count  A_following_count  A_listed_count  A_mentions_received  \
# 0               NaN                NaN             NaN                  NaN
# 1               NaN                NaN             NaN                  NaN
# 2               NaN                NaN             NaN                  NaN
# 3               NaN                NaN             NaN                  NaN
# 4               NaN                NaN             NaN                  NaN
#
#    A_mentions_sent  A_network_feature_1  A_network_feature_2  \
# 0              NaN                  NaN                  NaN
# 1              NaN                  NaN                  NaN
# 2              NaN                  NaN                  NaN
# 3              NaN                  NaN                  NaN
# 4              NaN                  NaN                  NaN
#
#    A_network_feature_3  A_posts  A_retweets_received    ...     \
# 0                  NaN      NaN                  NaN    ...
# ...

# %%
X_train = pre.proc(X_train_A) - pre.proc(X_train_B)

# %%
X_train.head()
# Out:
#    A_follower_count  A_following_count  A_listed_count  A_mentions_received  \
# 0               NaN                NaN             NaN                  NaN
# 1               NaN                NaN             NaN                  NaN
# 2               NaN                NaN             NaN                  NaN
# 3               NaN                NaN             NaN                  NaN
# 4               NaN                NaN             NaN                  NaN
#
#    A_mentions_sent  A_network_feature_1  A_network_feature_2  \
# 0              NaN                  NaN                  NaN
# 1              NaN                  NaN                  NaN
# 2              NaN                  NaN                  NaN
# 3              NaN                  NaN                  NaN
# 4              NaN                  NaN                  NaN
#
#    A_network_feature_3  A_posts  A_retweets_received    ...     \
# 0                  NaN      NaN                  NaN    ...
# ...

# %%
X_train_A.head()
# Out:
#    A_follower_count  A_following_count  A_listed_count  A_mentions_received  \
# 0               228                302               3             0.583979
# 1             21591               1179             228            90.456506
# 2              7310               1215             101            25.503644
# 3                20                  7               2             7.690824
# 4             45589                862            2641           148.854279
#
#    A_retweets_received  A_mentions_sent  A_retweets_sent    A_posts  \
# 0             0.100503         0.100503         0.100503   0.362150
# 1            25.798292         5.709329         1.111159   5.176620
# 2             9.556347         5.361519         0.591206   3.589718
# 3             0.277306         1.331508         0.100503   2.830627
# 4            36.998884        27.881768         3.333492  23.861282
#
#    A_network_feature_1  A_network_feature_2  A_network_feature_3      ratio
# ...

# %%
pre.proc(X_train_A).head()
# Out:
#    A_follower_count  A_following_count  A_listed_count  A_mentions_received  \
# 0          5.433722           5.713733        1.386294             0.459940
# 1          9.980078           7.073270        5.433722             4.515864
# 2          8.897135           7.103322        4.624973             3.277282
# 3          3.044522           2.079442        1.098612             2.162268
# 4         10.727444           6.760415        7.879291             5.009663
#
#    A_retweets_received  A_mentions_sent  A_retweets_sent   A_posts  \
# 0             0.095768         0.095768         0.095768  0.309064
# 1             3.288338         1.903499         0.747237  1.820771
# 2             2.356727         1.850267         0.464492  1.523819
# 3             0.244753         0.846515         0.095768  1.343028
# 4             3.637557         3.363211         1.466374  3.213312
#
#    A_network_feature_1  A_network_feature_2  A_network_feature_3     ratio
# ...

# %%
pre.proc(X_train_B).head()
# Out:
#    B_follower_count  B_following_count  B_listed_count  B_mentions_received  \
# 0         10.447671          10.302566        7.432484             2.799139
# 1         10.578038           6.744059        7.384610             3.725573
# 2          8.195058           6.180017        5.332719             0.550832
# 3          9.881395           9.777811        5.631212             6.352411
# 4          8.929965           7.445418        5.204007             3.118032
#
#    B_retweets_received  B_mentions_sent  B_retweets_sent   B_posts  \
# 0             1.606239         2.219674         0.286999  2.078042
# 1             2.296930         1.441653         0.447466  0.727704
# 2             0.303343         0.472003         0.095768  0.472003
# 3             5.969458         3.351728         2.100170  3.499591
# 4             1.522062         2.049582         0.751287  1.716182
#
#    B_network_feature_1  B_network_feature_2  B_network_feature_3     ratio
# ...

# %%
(pre.proc(X_train_A) - pre.proc(X_train_B)).head()
# Out:
#    A_follower_count  A_following_count  A_listed_count  A_mentions_received  \
# 0               NaN                NaN             NaN                  NaN
# 1               NaN                NaN             NaN                  NaN
# 2               NaN                NaN             NaN                  NaN
# 3               NaN                NaN             NaN                  NaN
# 4               NaN                NaN             NaN                  NaN
#
#    A_mentions_sent  A_network_feature_1  A_network_feature_2  \
# 0              NaN                  NaN                  NaN
# 1              NaN                  NaN                  NaN
# 2              NaN                  NaN                  NaN
# 3              NaN                  NaN                  NaN
# 4              NaN                  NaN                  NaN
#
#    A_network_feature_3  A_posts  A_retweets_received    ...     \
# 0                  NaN      NaN                  NaN    ...
# ...

# %%
( (pre.proc(X_train_A)).substract(pre.proc(X_train_B)) ).head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-e9cd4d36270f> in <module>()
# ----> 1 ( (pre.proc(X_train_A)).substract(pre.proc(X_train_B)) ).head()
#
# /home/ilias/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    1945                 return self[name]
#    1946             raise AttributeError("'%s' object has no attribute '%s'" %
# -> 1947                                  (type(self).__name__, name))
#    1948
#    1949     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'substract'

# %%
( (pre.proc(X_train_A)).subtract(pre.proc(X_train_B)) ).head()
# Out:
#    A_follower_count  A_following_count  A_listed_count  A_mentions_received  \
# 0               NaN                NaN             NaN                  NaN
# 1               NaN                NaN             NaN                  NaN
# 2               NaN                NaN             NaN                  NaN
# 3               NaN                NaN             NaN                  NaN
# 4               NaN                NaN             NaN                  NaN
#
#    A_mentions_sent  A_network_feature_1  A_network_feature_2  \
# 0              NaN                  NaN                  NaN
# 1              NaN                  NaN                  NaN
# 2              NaN                  NaN                  NaN
# 3              NaN                  NaN                  NaN
# 4              NaN                  NaN                  NaN
#
#    A_network_feature_3  A_posts  A_retweets_received    ...     \
# 0                  NaN      NaN                  NaN    ...
# ...

# %%
( (pre.proc(X_train_A)).sub(pre.proc(X_train_B)) ).head()
# Out:
#    A_follower_count  A_following_count  A_listed_count  A_mentions_received  \
# 0               NaN                NaN             NaN                  NaN
# 1               NaN                NaN             NaN                  NaN
# 2               NaN                NaN             NaN                  NaN
# 3               NaN                NaN             NaN                  NaN
# 4               NaN                NaN             NaN                  NaN
#
#    A_mentions_sent  A_network_feature_1  A_network_feature_2  \
# 0              NaN                  NaN                  NaN
# 1              NaN                  NaN                  NaN
# 2              NaN                  NaN                  NaN
# 3              NaN                  NaN                  NaN
# 4              NaN                  NaN                  NaN
#
#    A_network_feature_3  A_posts  A_retweets_received    ...     \
# 0                  NaN      NaN                  NaN    ...
# ...

# %%
( (pre.proc(X_train_A)).rsub(pre.proc(X_train_B)) ).head()
# Out:
#    A_follower_count  A_following_count  A_listed_count  A_mentions_received  \
# 0               NaN                NaN             NaN                  NaN
# 1               NaN                NaN             NaN                  NaN
# 2               NaN                NaN             NaN                  NaN
# 3               NaN                NaN             NaN                  NaN
# 4               NaN                NaN             NaN                  NaN
#
#    A_mentions_sent  A_network_feature_1  A_network_feature_2  \
# 0              NaN                  NaN                  NaN
# 1              NaN                  NaN                  NaN
# 2              NaN                  NaN                  NaN
# 3              NaN                  NaN                  NaN
# 4              NaN                  NaN                  NaN
#
#    A_network_feature_3  A_posts  A_retweets_received    ...     \
# 0                  NaN      NaN                  NaN    ...
# ...

# %%
A = pre.proc(X_train_A)

# %%
B = pre.proc(X_train_B)

# %%
(A-B).head()
# Out:
#    A_follower_count  A_following_count  A_listed_count  A_mentions_received  \
# 0               NaN                NaN             NaN                  NaN
# 1               NaN                NaN             NaN                  NaN
# 2               NaN                NaN             NaN                  NaN
# 3               NaN                NaN             NaN                  NaN
# 4               NaN                NaN             NaN                  NaN
#
#    A_mentions_sent  A_network_feature_1  A_network_feature_2  \
# 0              NaN                  NaN                  NaN
# 1              NaN                  NaN                  NaN
# 2              NaN                  NaN                  NaN
# 3              NaN                  NaN                  NaN
# 4              NaN                  NaN                  NaN
#
#    A_network_feature_3  A_posts  A_retweets_received    ...     \
# 0                  NaN      NaN                  NaN    ...
# ...

# %%
A.subtract(B).header()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-23-b4133e09db85> in <module>()
# ----> 1 A.subtract(B).header()
#
# /home/ilias/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    1945                 return self[name]
#    1946             raise AttributeError("'%s' object has no attribute '%s'" %
# -> 1947                                  (type(self).__name__, name))
#    1948
#    1949     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'header'

# %%
A.subtract(B).head()
# Out:
#    A_follower_count  A_following_count  A_listed_count  A_mentions_received  \
# 0               NaN                NaN             NaN                  NaN
# 1               NaN                NaN             NaN                  NaN
# 2               NaN                NaN             NaN                  NaN
# 3               NaN                NaN             NaN                  NaN
# 4               NaN                NaN             NaN                  NaN
#
#    A_mentions_sent  A_network_feature_1  A_network_feature_2  \
# 0              NaN                  NaN                  NaN
# 1              NaN                  NaN                  NaN
# 2              NaN                  NaN                  NaN
# 3              NaN                  NaN                  NaN
# 4              NaN                  NaN                  NaN
#
#    A_network_feature_3  A_posts  A_retweets_received    ...     \
# 0                  NaN      NaN                  NaN    ...
# ...

# %%
A.sub(B, axis='index')
# Out:
#       A_follower_count  A_following_count  A_listed_count  \
# 0                  NaN                NaN             NaN
# 1                  NaN                NaN             NaN
# 2                  NaN                NaN             NaN
# 3                  NaN                NaN             NaN
# 4                  NaN                NaN             NaN
# 5                  NaN                NaN             NaN
# 6                  NaN                NaN             NaN
# 7                  NaN                NaN             NaN
# 8                  NaN                NaN             NaN
# 9                  NaN                NaN             NaN
# 10                 NaN                NaN             NaN
# 11                 NaN                NaN             NaN
# 12                 NaN                NaN             NaN
# 13                 NaN                NaN             NaN
# 14                 NaN                NaN             NaN
# ...

# %%
A.sub(B, axis='column')
# Out:
#       A_follower_count  A_following_count  A_listed_count  \
# 0                  NaN                NaN             NaN
# 1                  NaN                NaN             NaN
# 2                  NaN                NaN             NaN
# 3                  NaN                NaN             NaN
# 4                  NaN                NaN             NaN
# 5                  NaN                NaN             NaN
# 6                  NaN                NaN             NaN
# 7                  NaN                NaN             NaN
# 8                  NaN                NaN             NaN
# 9                  NaN                NaN             NaN
# 10                 NaN                NaN             NaN
# 11                 NaN                NaN             NaN
# 12                 NaN                NaN             NaN
# 13                 NaN                NaN             NaN
# 14                 NaN                NaN             NaN
# ...

# %%
A[A_follower_count] - B[B_follower_count]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-0cb8cc9d8e79> in <module>()
# ----> 1 A[A_follower_count] - B[B_follower_count]
#
# NameError: name 'A_follower_count' is not defined

# %%
A['A_follower_count'] - B['B_follower_count']
# Out:
# 0    -5.013949
# 1    -0.597960
# 2     0.702078
# 3    -6.836873
# 4     1.797479
# 5     3.243808
# 6     0.431383
# 7     0.158206
# 8     2.029903
# 9     0.437337
# 10   -4.613207
# 11   -3.079470
# 12    3.431837
# 13    2.959052
# 14   -0.770055
# ...
# 5485    7.417514
# 5486   -1.449070
# 5487    5.856309
# 5488    3.525826
# 5489   -5.092435
# 5490   -0.252983
# 5491   -1.776600
# 5492   -8.592218
# 5493   -0.992892
# 5494    3.101307
# 5495   -2.958008
# 5496   -1.950954
# 5497    0.711248
# 5498   -0.195964
# 5499   -6.686210
# Length: 5500, dtype: float64

# %%
A.ix[:,:] - B.ix[:,:]
# Out:
#       A_follower_count  A_following_count  A_listed_count  \
# 0                  NaN                NaN             NaN
# 1                  NaN                NaN             NaN
# 2                  NaN                NaN             NaN
# 3                  NaN                NaN             NaN
# 4                  NaN                NaN             NaN
# 5                  NaN                NaN             NaN
# 6                  NaN                NaN             NaN
# 7                  NaN                NaN             NaN
# 8                  NaN                NaN             NaN
# 9                  NaN                NaN             NaN
# 10                 NaN                NaN             NaN
# 11                 NaN                NaN             NaN
# 12                 NaN                NaN             NaN
# 13                 NaN                NaN             NaN
# 14                 NaN                NaN             NaN
# ...

# %%
A.ix[:,'A_follower_count'] - B.ix[:,'B_follower_count']
# Out:
# 0    -5.013949
# 1    -0.597960
# 2     0.702078
# 3    -6.836873
# 4     1.797479
# 5     3.243808
# 6     0.431383
# 7     0.158206
# 8     2.029903
# 9     0.437337
# 10   -4.613207
# 11   -3.079470
# 12    3.431837
# 13    2.959052
# 14   -0.770055
# ...
# 5485    7.417514
# 5486   -1.449070
# 5487    5.856309
# 5488    3.525826
# 5489   -5.092435
# 5490   -0.252983
# 5491   -1.776600
# 5492   -8.592218
# 5493   -0.992892
# 5494    3.101307
# 5495   -2.958008
# 5496   -1.950954
# 5497    0.711248
# 5498   -0.195964
# 5499   -6.686210
# Length: 5500, dtype: float64

# %%
A.ix[:,A.head()] - B.ix[:,B.head()]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-164409088b72> in <module>()
# ----> 1 A.ix[:,A.head()] - B.ix[:,B.head()]
#
# /home/ilias/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in __getitem__(self, key)
#      68                 pass
#      69
# ---> 70             return self._getitem_tuple(key)
#      71         else:
#      72             return self._getitem_axis(key, axis=0)
#
# /home/ilias/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_tuple(self, tup)
#     717                 continue
#     718
# --> 719             retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     720
#     721         return retval
#
# /home/ilias/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_axis(self, key, axis)
#     910
#     911             if hasattr(key, 'ndim') and key.ndim > 1:
# ...

# %%
list(A.columns.values)
# Out:
# ['A_follower_count',
#  'A_following_count',
#  'A_listed_count',
#  'A_mentions_received',
#  'A_retweets_received',
#  'A_mentions_sent',
#  'A_retweets_sent',
#  'A_posts',
#  'A_network_feature_1',
#  'A_network_feature_2',
#  'A_network_feature_3',
#  'ratio']

# %%
A.columns.values
# Out:
# array(['A_follower_count', 'A_following_count', 'A_listed_count',
#        'A_mentions_received', 'A_retweets_received', 'A_mentions_sent',
#        'A_retweets_sent', 'A_posts', 'A_network_feature_1',
#        'A_network_feature_2', 'A_network_feature_3', 'ratio'], dtype=object)

# %%
A.ix[:,A.columns.values] - B.ix[:,B.columns.values]
# Out:
#       A_follower_count  A_following_count  A_listed_count  \
# 0                  NaN                NaN             NaN
# 1                  NaN                NaN             NaN
# 2                  NaN                NaN             NaN
# 3                  NaN                NaN             NaN
# 4                  NaN                NaN             NaN
# 5                  NaN                NaN             NaN
# 6                  NaN                NaN             NaN
# 7                  NaN                NaN             NaN
# 8                  NaN                NaN             NaN
# 9                  NaN                NaN             NaN
# 10                 NaN                NaN             NaN
# 11                 NaN                NaN             NaN
# 12                 NaN                NaN             NaN
# 13                 NaN                NaN             NaN
# 14                 NaN                NaN             NaN
# ...

# %%
A.ix[:,list(A.columns.values)] - B.ix[:,list(B.columns.values)]
# Out:
#       A_follower_count  A_following_count  A_listed_count  \
# 0                  NaN                NaN             NaN
# 1                  NaN                NaN             NaN
# 2                  NaN                NaN             NaN
# 3                  NaN                NaN             NaN
# 4                  NaN                NaN             NaN
# 5                  NaN                NaN             NaN
# 6                  NaN                NaN             NaN
# 7                  NaN                NaN             NaN
# 8                  NaN                NaN             NaN
# 9                  NaN                NaN             NaN
# 10                 NaN                NaN             NaN
# 11                 NaN                NaN             NaN
# 12                 NaN                NaN             NaN
# 13                 NaN                NaN             NaN
# 14                 NaN                NaN             NaN
# ...

# %%
A.ix[:,'A_follower_count','A_following_count'] - B.ix[:,'B_follower_count','B_following_count']
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-36-f0dc2ddf49b8> in <module>()
# ----> 1 A.ix[:,'A_follower_count','A_following_count'] - B.ix[:,'B_follower_count','B_following_count']
#
# /home/ilias/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in __getitem__(self, key)
#      68                 pass
#      69
# ---> 70             return self._getitem_tuple(key)
#      71         else:
#      72             return self._getitem_axis(key, axis=0)
#
# /home/ilias/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_tuple(self, tup)
#     702
#     703         # no multi-index, so validate all of the indexers
# --> 704         self._has_valid_tuple(tup)
#     705
#     706         # ugly hack for GH #836
#
# /home/ilias/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in _has_valid_tuple(self, key)
# ...

# %%
A.ix[:,'A_follower_count':'A_following_count'] - B.ix[:,'B_follower_count':'B_following_count']
# Out:
#       A_follower_count  A_following_count  B_follower_count  B_following_count
# 0                  NaN                NaN               NaN                NaN
# 1                  NaN                NaN               NaN                NaN
# 2                  NaN                NaN               NaN                NaN
# 3                  NaN                NaN               NaN                NaN
# 4                  NaN                NaN               NaN                NaN
# 5                  NaN                NaN               NaN                NaN
# 6                  NaN                NaN               NaN                NaN
# 7                  NaN                NaN               NaN                NaN
# 8                  NaN                NaN               NaN                NaN
# 9                  NaN                NaN               NaN                NaN
# 10                 NaN                NaN               NaN                NaN
# ...

# %%
list(A.columns.values)
# Out:
# ['A_follower_count',
#  'A_following_count',
#  'A_listed_count',
#  'A_mentions_received',
#  'A_retweets_received',
#  'A_mentions_sent',
#  'A_retweets_sent',
#  'A_posts',
#  'A_network_feature_1',
#  'A_network_feature_2',
#  'A_network_feature_3',
#  'ratio']

# %%
A.rename(columns{ 'A_follower_count':'follower_count',
 'A_following_count':'following_count',
 'A_listed_count':'listed_count',
 'A_mentions_received':'mentions_received',
 'A_retweets_received':'retweets_received',
 'A_mentions_sent':'mentions_sent',
 'A_retweets_sent':'retweets_sent',
 'A_posts':'posts',
 'A_network_feature_1':'network_feature_1',
 'A_network_feature_2':'network_feature_2',
 'A_network_feature_3':'network_feature_3'}, inplace= True)
# Out:
#   File "<ipython-input-39-4fda930c8f2f>", line 1
#     A.rename(columns{ 'A_follower_count':'follower_count',
#                     ^
# SyntaxError: invalid syntax

# %%
A.rename(columns={ 'A_follower_count':'follower_count',
 'A_following_count':'following_count',
 'A_listed_count':'listed_count',
 'A_mentions_received':'mentions_received',
 'A_retweets_received':'retweets_received',
 'A_mentions_sent':'mentions_sent',
 'A_retweets_sent':'retweets_sent',
 'A_posts':'posts',
 'A_network_feature_1':'network_feature_1',
 'A_network_feature_2':'network_feature_2',
 'A_network_feature_3':'network_feature_3'}, inplace= True)

# %%
A.head()
# Out:
#    follower_count  following_count  listed_count  mentions_received  \
# 0        5.433722         5.713733      1.386294           0.459940
# 1        9.980078         7.073270      5.433722           4.515864
# 2        8.897135         7.103322      4.624973           3.277282
# 3        3.044522         2.079442      1.098612           2.162268
# 4       10.727444         6.760415      7.879291           5.009663
#
#    retweets_received  mentions_sent  retweets_sent     posts  \
# 0           0.095768       0.095768       0.095768  0.309064
# 1           3.288338       1.903499       0.747237  1.820771
# 2           2.356727       1.850267       0.464492  1.523819
# 3           0.244753       0.846515       0.095768  1.343028
# 4           3.637557       3.363211       1.466374  3.213312
#
#    network_feature_1  network_feature_2  network_feature_3     ratio
# 0           1.098612           5.120983           9.337502  0.562450
# ...

# %%
B.rename(columns={ 'B_follower_count':'follower_count',
 'B_following_count':'following_count',
 'B_listed_count':'listed_count',
 'B_mentions_received':'mentions_received',
 'B_retweets_received':'retweets_received',
 'B_mentions_sent':'mentions_sent',
 'B_retweets_sent':'retweets_sent',
 'B_posts':'posts',
 'B_network_feature_1':'network_feature_1',
 'B_network_feature_2':'network_feature_2',
 'B_network_feature_3':'network_feature_3'}, inplace= True)

# %%
(A-B).head()
# Out:
#    follower_count  following_count  listed_count  mentions_received  \
# 0       -5.013949        -4.588833     -6.046189          -2.339199
# 1       -0.597960         0.329211     -1.950888           0.790290
# 2        0.702078         0.923305     -0.707746           2.726450
# 3       -6.836873        -7.698369     -4.532599          -4.190144
# 4        1.797479        -0.685003      2.675285           1.891631
#
#    retweets_received  mentions_sent  retweets_sent     posts  \
# 0          -1.510471      -2.123906      -0.191231 -1.768978
# 1           0.991408       0.461846       0.299771  1.093068
# 2           2.053384       1.378264       0.368724  1.051816
# 3          -5.724705      -2.505213      -2.004402 -2.156562
# 4           2.115495       1.313628       0.715086  1.497130
#
#    network_feature_1  network_feature_2  network_feature_3     ratio
# 0          -3.106080           0.783297           1.778519 -0.205882
# ...

# %%
from sklearn import linear_model
from sklearn import metrics
from sklearn.ensemble import GradientBoostingClassifier
import numpy as np
import pandas as pd
import load_data2 as load_data
import preprocess2 as pre

# %%
X_train_A, X_train_B, y_train = load_data.load("train")
X_test_A, X_test_B = load_data.load("test")

# %%
X_train_A, X_train_B = pre.common_name(A,B)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-15c02b2f50f4> in <module>()
# ----> 1 X_train_A, X_train_B = pre.common_name(A,B)
#
# NameError: name 'A' is not defined

# %%
X_train_A, X_train_B = pre.common_name(X_train_A,X_train_B)

# %%
X_train_A - X_train_B
# Out:
#       follower_count  following_count  listed_count  mentions_received  \
# 0             -34235           -29506         -1686         -14.846518
# 1             -17671              331         -1382          49.961485
# 2               3688              733          -105          24.768949
# 3             -19542           -17630          -276        -565.184032
# 4              38035             -849          2460         127.252413
# 5             274588           274751          2943         -21.264931
# 6             100119           275250        -11700        -246.686292
# 7               1392             -698          -746          44.798426
# 8            1975203             3973          5737        6289.148959
# 9              64685              103         -6119         -43.910320
# 10           -319482           -34345        -22086        -176.243524
# 11            -81224           -65608         -4938        -147.936244
# ...

# %%
X_train = pre.proc(X_train_A) - pre.proc(X_train_B)

# %%
model = linear_model.LogisticRegression(fit_intercept=False)

# %%
model.fit(X_train,y_train)
# Out:
# /home/ilias/anaconda/lib/python2.7/site-packages/sklearn/preprocessing/label.py:125: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-27c89f04d08a> in <module>()
# ----> 1 model.fit(X_train,y_train)
#
# /home/ilias/anaconda/lib/python2.7/site-packages/sklearn/svm/base.pyc in fit(self, X, y)
#     677                              " one.")
#     678
# --> 679         X = atleast2d_or_csr(X, dtype=np.float64, order="C")
#     680
#     681         self.class_weight_ = compute_class_weight(self.class_weight,
#
# /home/ilias/anaconda/lib/python2.7/site-packages/sklearn/utils/validation.pyc in atleast2d_or_csr(X, dtype, order, copy, force_all_finite)
# ...

# %%
X_train
# Out:
#       follower_count  following_count  listed_count  mentions_received  \
# 0          -5.013949        -4.588833     -6.046189          -2.339199
# 1          -0.597960         0.329211     -1.950888           0.790290
# 2           0.702078         0.923305     -0.707746           2.726450
# 3          -6.836873        -7.698369     -4.532599          -4.190144
# 4           1.797479        -0.685003      2.675285           1.891631
# 5           3.243808         5.215182      1.973496          -0.715942
# 6           0.431383         5.619315     -1.486831          -2.575322
# 7           0.158206        -4.001723     -1.500957           1.848947
# 8           2.029903         2.103825      0.654319           2.619180
# 9           0.437337         0.076249     -0.954286          -0.261614
# 10         -4.613207        -2.446251     -5.018900          -4.924369
# 11         -3.079470        -3.840766     -3.425792          -3.794518
# ...

# %%
X_train.isnull().sum().sum(
# Out:
#   File "<ipython-input-10-44df7f19e186>", line 1
#     X_train.isnull().sum().sum(
#                                ^
# SyntaxError: unexpected EOF while parsing

# %%
X_train.isnull().sum().sum()
# Out:
# 0

# %%
y_train.isnull().sum().sum(
# Out:
#   File "<ipython-input-12-8c025aee25e0>", line 1
#     y_train.isnull().sum().sum(
#                                ^
# SyntaxError: unexpected EOF while parsing

# %%
y_train.isnull().sum().sum()
# Out:
# 0

# %%
ravel(y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-24fdc38763ac> in <module>()
# ----> 1 ravel(y_train)
#
# NameError: name 'ravel' is not defined

# %%
np.ravel(y_train)
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
X_train.isnull()
# Out:
#      follower_count following_count listed_count mentions_received  \
# 0             False           False        False             False
# 1             False           False        False             False
# 2             False           False        False             False
# 3             False           False        False             False
# 4             False           False        False             False
# 5             False           False        False             False
# 6             False           False        False             False
# 7             False           False        False             False
# 8             False           False        False             False
# 9             False           False        False             False
# 10            False           False        False             False
# 11            False           False        False             False
# 12            False           False        False             False
# ...

# %%
X_train.isnull().sum()
# Out:
# follower_count       0
# following_count      0
# listed_count         0
# mentions_received    0
# retweets_received    0
# mentions_sent        0
# retweets_sent        0
# posts                0
# network_feature_1    0
# network_feature_2    0
# network_feature_3    0
# ratio                0
# dtype: int64

# %%
model.fit(X_train,y_train)
# Out:
# /home/ilias/anaconda/lib/python2.7/site-packages/sklearn/preprocessing/label.py:125: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-27c89f04d08a> in <module>()
# ----> 1 model.fit(X_train,y_train)
#
# /home/ilias/anaconda/lib/python2.7/site-packages/sklearn/svm/base.pyc in fit(self, X, y)
#     677                              " one.")
#     678
# --> 679         X = atleast2d_or_csr(X, dtype=np.float64, order="C")
#     680
#     681         self.class_weight_ = compute_class_weight(self.class_weight,
#
# /home/ilias/anaconda/lib/python2.7/site-packages/sklearn/utils/validation.pyc in atleast2d_or_csr(X, dtype, order, copy, force_all_finite)
# ...

# %%
y_train.shape
# Out:
# (5500, 1)

# %%
y_train.single_column.values
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-7422b0c60c3f> in <module>()
# ----> 1 y_train.single_column.values
#
# /home/ilias/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    1945                 return self[name]
#    1946             raise AttributeError("'%s' object has no attribute '%s'" %
# -> 1947                                  (type(self).__name__, name))
#    1948
#    1949     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'single_column'

# %%
y_train.head()
# Out:
#    Choice
# 0       0
# 1       0
# 2       0
# 3       0
# 4       1

# %%
model.fit(X_train,y_train['Choice'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-a252f888cdbf> in <module>()
# ----> 1 model.fit(X_train,y_train['Choice'])
#
# /home/ilias/anaconda/lib/python2.7/site-packages/sklearn/svm/base.pyc in fit(self, X, y)
#     677                              " one.")
#     678
# --> 679         X = atleast2d_or_csr(X, dtype=np.float64, order="C")
#     680
#     681         self.class_weight_ = compute_class_weight(self.class_weight,
#
# /home/ilias/anaconda/lib/python2.7/site-packages/sklearn/utils/validation.pyc in atleast2d_or_csr(X, dtype, order, copy, force_all_finite)
#     163     return _atleast2d_or_sparse(X, dtype, order, copy, sp.csr_matrix,
#     164                                 "tocsr", sp.isspmatrix_csr,
# --> 165                                 force_all_finite)
#     166
#     167
#
# ...

# %%
features = list(X_train.columns.values)

# %%
model.fit(X_train[features],y_train['Choice'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-12449d1bb495> in <module>()
# ----> 1 model.fit(X_train[features],y_train['Choice'])
#
# /home/ilias/anaconda/lib/python2.7/site-packages/sklearn/svm/base.pyc in fit(self, X, y)
#     677                              " one.")
#     678
# --> 679         X = atleast2d_or_csr(X, dtype=np.float64, order="C")
#     680
#     681         self.class_weight_ = compute_class_weight(self.class_weight,
#
# /home/ilias/anaconda/lib/python2.7/site-packages/sklearn/utils/validation.pyc in atleast2d_or_csr(X, dtype, order, copy, force_all_finite)
#     163     return _atleast2d_or_sparse(X, dtype, order, copy, sp.csr_matrix,
#     164                                 "tocsr", sp.isspmatrix_csr,
# --> 165                                 force_all_finite)
#     166
#     167
#
# ...

# %%
features
# Out:
# ['follower_count',
#  'following_count',
#  'listed_count',
#  'mentions_received',
#  'retweets_received',
#  'mentions_sent',
#  'retweets_sent',
#  'posts',
#  'network_feature_1',
#  'network_feature_2',
#  'network_feature_3',
#  'ratio']

# %%
model.fit(X_train['ratio'],y_train['Choice'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-28812d7052b5> in <module>()
# ----> 1 model.fit(X_train['ratio'],y_train['Choice'])
#
# /home/ilias/anaconda/lib/python2.7/site-packages/sklearn/svm/base.pyc in fit(self, X, y)
#     677                              " one.")
#     678
# --> 679         X = atleast2d_or_csr(X, dtype=np.float64, order="C")
#     680
#     681         self.class_weight_ = compute_class_weight(self.class_weight,
#
# /home/ilias/anaconda/lib/python2.7/site-packages/sklearn/utils/validation.pyc in atleast2d_or_csr(X, dtype, order, copy, force_all_finite)
#     163     return _atleast2d_or_sparse(X, dtype, order, copy, sp.csr_matrix,
#     164                                 "tocsr", sp.isspmatrix_csr,
# --> 165                                 force_all_finite)
#     166
#     167
#
# ...

# %%
X_train['ratio'].head()
# Out:
# 0   -0.205882
# 1   -0.895723
# 2   -0.193514
# 3    0.603644
# 4    2.297732
# Name: ratio, dtype: float64

# %%
y_train['Choice']
# Out:
# 0     0
# 1     0
# 2     0
# 3     0
# 4     1
# 5     0
# 6     0
# 7     1
# 8     1
# 9     0
# 10    0
# 11    0
# 12    1
# 13    0
# 14    1
# ...
# 5485    1
# 5486    0
# 5487    1
# 5488    1
# 5489    0
# 5490    1
# 5491    0
# 5492    0
# 5493    0
# 5494    1
# 5495    0
# 5496    1
# 5497    0
# 5498    0
# 5499    0
# Name: Choice, Length: 5500, dtype: int64

# %%
model.fit(X_train['follower_count'],y_train['Choice'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-c337d8262cc3> in <module>()
# ----> 1 model.fit(X_train['follower_count'],y_train['Choice'])
#
# /home/ilias/anaconda/lib/python2.7/site-packages/sklearn/svm/base.pyc in fit(self, X, y)
#     685             raise ValueError("X and y have incompatible shapes.\n"
#     686                              "X has %s samples, but y has %s." %
# --> 687                              (X.shape[0], y_ind.shape[0]))
#     688
#     689         liblinear.set_verbosity_wrap(self.verbose)
#
# ValueError: X and y have incompatible shapes.
# X has 1 samples, but y has 5500.

# %%
X_train
# Out:
#       follower_count  following_count  listed_count  mentions_received  \
# 0          -5.013949        -4.588833     -6.046189          -2.339199
# 1          -0.597960         0.329211     -1.950888           0.790290
# 2           0.702078         0.923305     -0.707746           2.726450
# 3          -6.836873        -7.698369     -4.532599          -4.190144
# 4           1.797479        -0.685003      2.675285           1.891631
# 5           3.243808         5.215182      1.973496          -0.715942
# 6           0.431383         5.619315     -1.486831          -2.575322
# 7           0.158206        -4.001723     -1.500957           1.848947
# 8           2.029903         2.103825      0.654319           2.619180
# 9           0.437337         0.076249     -0.954286          -0.261614
# 10         -4.613207        -2.446251     -5.018900          -4.924369
# 11         -3.079470        -3.840766     -3.425792          -3.794518
# ...

# %%
model.fit(X_train[:,'follower_count'],y_train['Choice'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-78ddb38a17b1> in <module>()
# ----> 1 model.fit(X_train[:,'follower_count'],y_train['Choice'])
#
# /home/ilias/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1778             return self._getitem_multilevel(key)
#    1779         else:
# -> 1780             return self._getitem_column(key)
#    1781
#    1782     def _getitem_column(self, key):
#
# /home/ilias/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    1785         # get column
#    1786         if self.columns.is_unique:
# -> 1787             return self._get_item_cache(key)
#    1788
#    1789         # duplicate columns & possible reduce dimensionaility
#
# /home/ilias/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
# ...

# %%
from sklearn import linear_model
from sklearn import metrics
from sklearn.ensemble import GradientBoostingClassifier
import numpy as np
import pandas as pd
import load_data2 as load_data
import preprocess2 as pre

X_train_A, X_train_B, y_train = load_data.load("train")
X_test_A, X_test_B = load_data.load("test")

# %%
X_train_A, X_train_B = pre.common_name(X_train_A,X_train_B)

# %%
X_train = X_train_A - X_train_B

# %%
model = linear_model.LogisticRegression(fit_intercept=False)
#params = {'n_estimators':200, 'learning_rate':0.1,'max_depth':3, 'random_state':0}
#model = GradientBoostingClassifier(**params)
model.fit(X_train,y_train)
# Out:
# /home/ilias/anaconda/lib/python2.7/site-packages/sklearn/preprocessing/label.py:125: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=False,
#           intercept_scaling=1, penalty='l2', random_state=None, tol=0.0001)

# %%
preds = model.predict_proba(X_train)[:,1]
fpr, tpr, thresholds = metrics.roc_curve(y_train, preds)
auc = metrics.auc(fpr,tpr)

# %%
print 'AuC score on training data:',auc
# Out:
# AuC score on training data: 0.795546070291

# %%
A = X_train_A.apply(np.log1p)

# %%
B = X_train_B.apply(np.log1p)

# %%
X = A - B

# %%
model.fit(X,y_train)
# Out:
# /home/ilias/anaconda/lib/python2.7/site-packages/sklearn/preprocessing/label.py:125: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=False,
#           intercept_scaling=1, penalty='l2', random_state=None, tol=0.0001)

# %%
from sklearn import linear_model
from sklearn import metrics
from sklearn.ensemble import GradientBoostingClassifier
import numpy as np
import pandas as pd
import load_data2 as load_data
import preprocess2 as pre

X_train_A, X_train_B, y_train = load_data.load("train")
X_test_A, X_test_B = load_data.load("test")

# %%
X_train_A, X_train_B = pre.common_name(X_train_A,X_train_B)

# %%
A = pre.follow_ratio(X_train_A)

# %%
A['ratio'].astype(int)
# Out:
# 0         0
# 1        18
# 2         6
# 3         2
# 4        52
# 5         1
# 6         1
# 7       792
# 8       502
# 9       130
# 10        0
# 11        2
# 12       46
# 13    16685
# 14        4
# ...
# 5485     307
# 5486       1
# 5487       5
# 5488     190
# 5489       3
# 5490    9200
# 5491       1
# 5492       0
# 5493     128
# 5494       1
# 5495     225
# 5496       0
# 5497      22
# 5498    1269
# 5499       0
# Name: ratio, Length: 5500, dtype: int64

# %%
A['ratio'].apply(np.round)
# Out:
# 0         1
# 1        18
# 2         6
# 3         3
# 4        53
# 5         1
# 6         1
# 7       793
# 8       503
# 9       130
# 10        1
# 11        3
# 12       47
# 13    16685
# 14        5
# ...
# 5485     307
# 5486       1
# 5487       6
# 5488     191
# 5489       3
# 5490    9200
# 5491       1
# 5492       1
# 5493     128
# 5494       1
# 5495     226
# 5496       0
# 5497      23
# 5498    1269
# 5499       1
# Name: ratio, Length: 5500, dtype: float64

# %%
from sklearn import linear_model
from sklearn import metrics
from sklearn.ensemble import GradientBoostingClassifier
import numpy as np
import pandas as pd
import load_data2 as load_data
import preprocess2 as pre

X_train_A, X_train_B, y_train = load_data.load("train")
X_test_A, X_test_B = load_data.load("test")

X_train_A, X_train_B = pre.common_name(X_train_A,X_train_B)

X_train = pre.proc(X_train_A) - pre.proc(X_train_B)

model = linear_model.LogisticRegression(fit_intercept=False)

# %%
model.fit(X_train,y_train['Choice'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-a252f888cdbf> in <module>()
# ----> 1 model.fit(X_train,y_train['Choice'])
#
# /home/ilias/anaconda/lib/python2.7/site-packages/sklearn/svm/base.pyc in fit(self, X, y)
#     677                              " one.")
#     678
# --> 679         X = atleast2d_or_csr(X, dtype=np.float64, order="C")
#     680
#     681         self.class_weight_ = compute_class_weight(self.class_weight,
#
# /home/ilias/anaconda/lib/python2.7/site-packages/sklearn/utils/validation.pyc in atleast2d_or_csr(X, dtype, order, copy, force_all_finite)
#     163     return _atleast2d_or_sparse(X, dtype, order, copy, sp.csr_matrix,
#     164                                 "tocsr", sp.isspmatrix_csr,
# --> 165                                 force_all_finite)
#     166
#     167
#
# ...

# %%
X_train['ratio']
# Out:
# 0     0.000000
# 1    -0.905709
# 2    -0.251314
# 3     0.693147
# 4     2.379546
# 5    -1.386294
# 6    -4.532599
# 7     4.192177
# 8    -0.074533
# 9     0.353409
# 10   -1.609438
# 11    0.693147
# 12    3.178054
# 13    3.006942
# 14    1.098612
# ...
# 5485    5.730100
# 5486   -4.158883
# 5487    0.000000
# 5488    3.178054
# 5489   -5.626721
# 5490    2.846672
# 5491   -0.405465
# 5492   -2.803360
# 5493   -2.840030
# 5494    0.000000
# 5495   -0.951777
# 5496   -1.098612
# 5497    1.568616
# 5498    4.844187
# 5499   -4.400603
# Name: ratio, Length: 5500, dtype: float64

# %%
X_train.isnull().sum()
# Out:
# follower_count       0
# following_count      0
# listed_count         0
# mentions_received    0
# retweets_received    0
# mentions_sent        0
# retweets_sent        0
# posts                0
# network_feature_1    0
# network_feature_2    0
# network_feature_3    0
# ratio                0
# dtype: int64

# %%
from sklearn import linear_model
from sklearn import metrics
from sklearn.ensemble import GradientBoostingClassifier
import numpy as np
import pandas as pd
import load_data2 as load_data
import preprocess2 as pre

X_train_A, X_train_B, y_train = load_data.load("train")
X_test_A, X_test_B = load_data.load("test")

X_train_A, X_train_B = pre.common_name(X_train_A,X_train_B)

X_train = pre.proc(X_train_A) - pre.proc(X_train_B)

model = linear_model.LogisticRegression(fit_intercept=False)
#params = {'n_estimators':200, 'learning_rate':0.1,'max_depth':3, 'random_state':0}
#model = GradientBoostingClassifier(**params)
model.fit(X_train,y_train['Choice'])

preds = model.predict_proba(X_train)[:,1]
fpr, tpr, thresholds = metrics.roc_curve(y_train, preds)
auc = metrics.auc(fpr,tpr)

#print 'AuC score on training data:',metrics.roc_auc_score(y_train,preds.T)
print 'AuC score on training data:',auc

###########################
# PREDICTING ON TEST DATA
###########################
X_test = pre.proc(X_test_A) - pre.proc(X_test_B)
# Out:
# AuC score on training data: 0.863082614928

# %%
preds_test = model.predict_proba(X_test)[:,1]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-6f5efef74fe3> in <module>()
# ----> 1 preds_test = model.predict_proba(X_test)[:,1]
#
# /home/ilias/anaconda/lib/python2.7/site-packages/sklearn/linear_model/logistic.pyc in predict_proba(self, X)
#     126             where classes are ordered as they are in ``self.classes_``.
#     127         """
# --> 128         return self._predict_proba_lr(X)
#     129
#     130     def predict_log_proba(self, X):
#
# /home/ilias/anaconda/lib/python2.7/site-packages/sklearn/linear_model/base.pyc in _predict_proba_lr(self, X)
#     227         multiclass is handled by normalizing that over all classes.
#     228         """
# --> 229         prob = self.decision_function(X)
#     230         prob *= -1
#     231         np.exp(prob, prob)
#
# ...

# %%
X_test.isnull().sum()
# Out:
# A_follower_count       5952
# A_following_count      5952
# A_listed_count         5952
# A_mentions_received    5952
# A_mentions_sent        5952
# A_network_feature_1    5952
# A_network_feature_2    5952
# A_network_feature_3    5952
# A_posts                5952
# A_retweets_received    5952
# A_retweets_sent        5952
# B_follower_count       5952
# B_following_count      5952
# B_listed_count         5952
# B_mentions_received    5952
# B_mentions_sent        5952
# B_network_feature_1    5952
# B_network_feature_2    5952
# B_network_feature_3    5952
# B_posts                5952
# B_retweets_received    5952
# B_retweets_sent        5952
# dtype: int64

# %%
pre.proc(X_test_A)
# Out:
#       A_follower_count  A_following_count  A_listed_count  \
# 0            13.328873           5.993961        8.653471
# 1            13.513840           9.280239        7.154615
# 2             8.199464           8.114325        4.454347
# 3             6.419995           7.138867        3.465736
# 4            14.117354           5.805135        9.658098
# 5             6.918695           6.922644        4.143135
# 6            15.594272           6.182085        8.935245
# 7            13.271723           7.937375        8.905444
# 8             5.899897           6.833032        1.945910
# 9            13.202305           7.669028        9.250234
# 10           13.395473           8.419801        8.730367
# 11           13.202305           7.669028        9.250234
# 12           13.536743           9.468851        7.179308
# 13           13.124449           8.098643        8.809116
# 14           10.793681          10.036531        6.838405
# ...

# %%
from sklearn import linear_model
from sklearn import metrics
from sklearn.ensemble import GradientBoostingClassifier
import numpy as np
import pandas as pd
import load_data2 as load_data
import preprocess2 as pre

X_train_A, X_train_B, y_train = load_data.load("train")
X_test_A, X_test_B = load_data.load("test")

X_train_A, X_train_B = pre.common_name(X_train_A,X_train_B)

# %%
A = pre.follow_ratio(X_train_A)

# %%
A.head()
# Out:
#    follower_count  following_count  listed_count  mentions_received  \
# 0             228              302             3           0.583979
# 1           21591             1179           228          90.456506
# 2            7310             1215           101          25.503644
# 3              20                7             2           7.690824
# 4           45589              862          2641         148.854279
#
#    retweets_received  mentions_sent  retweets_sent      posts  \
# 0           0.100503       0.100503       0.100503   0.362150
# 1          25.798292       5.709329       1.111159   5.176620
# 2           9.556347       5.361519       0.591206   3.589718
# 3           0.277306       1.331508       0.100503   2.830627
# 4          36.998884      27.881768       3.333492  23.861282
#
#    network_feature_1  network_feature_2  network_feature_3      ratio
# 0                  2         166.500000       11355.000000   0.754967
# ...

# %%
A['posts']
# Out:
# 0      0.362150
# 1      5.176620
# 2      3.589718
# 3      2.830627
# 4     23.861282
# 5      0.100503
# 6      0.100503
# 7      6.806045
# 8     66.206208
# 9     15.953243
# 10     0.362150
# 11     0.100503
# 12     9.827005
# 13    10.216532
# 14     0.100503
# ...
# 5485     21.063196
# 5486      0.100503
# 5487     42.813704
# 5488     22.231386
# 5489      0.351840
# 5490      5.559490
# 5491     10.691878
# 5492      0.100503
# 5493      0.356943
# 5494      2.532744
# 5495    104.438625
# 5496      0.603177
# 5497      6.503977
# 5498      7.498126
# 5499      2.953237
# Name: posts, Length: 5500, dtype: float64

# %%
B = pre.follow_ratio(X_train_B)

# %%
X = A-B

# %%
X.head()
# Out:
#    follower_count  following_count  listed_count  mentions_received  \
# 0          -34235           -29506         -1686         -14.846518
# 1          -17671              331         -1382          49.961485
# 2            3688              733          -105          24.768949
# 3          -19542           -17630          -276        -565.184032
# 4           38035             -849          2460         127.252413
#
#    retweets_received  mentions_sent  retweets_sent      posts  \
# 0          -3.883525      -8.103828      -0.231920  -6.626665
# 1          16.854685       2.481652       0.546816   4.106299
# 2           9.201969       4.758317       0.490702   2.986516
# 3        -390.016375     -26.220532      -7.067053 -29.271279
# 4          33.417223      21.117111       2.213765  19.298035
#
#    network_feature_1  network_feature_2  network_feature_3      ratio
# 0                -64          90.969697        9438.106061  -0.401199
# ...

# %%
X.isnull().sum()
# Out:
# follower_count       0
# following_count      0
# listed_count         0
# mentions_received    0
# retweets_received    0
# mentions_sent        0
# retweets_sent        0
# posts                0
# network_feature_1    0
# network_feature_2    0
# network_feature_3    0
# ratio                0
# dtype: int64

# %%
model.fit(X,y_train['Choice'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-410255f3397a> in <module>()
# ----> 1 model.fit(X,y_train['Choice'])
#
# NameError: name 'model' is not defined

# %%
model = linear_model.LogisticRegression(fit_intercept=False)

# %%
model.fit(X,y_train['Choice'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-410255f3397a> in <module>()
# ----> 1 model.fit(X,y_train['Choice'])
#
# /home/ilias/anaconda/lib/python2.7/site-packages/sklearn/svm/base.pyc in fit(self, X, y)
#     677                              " one.")
#     678
# --> 679         X = atleast2d_or_csr(X, dtype=np.float64, order="C")
#     680
#     681         self.class_weight_ = compute_class_weight(self.class_weight,
#
# /home/ilias/anaconda/lib/python2.7/site-packages/sklearn/utils/validation.pyc in atleast2d_or_csr(X, dtype, order, copy, force_all_finite)
#     163     return _atleast2d_or_sparse(X, dtype, order, copy, sp.csr_matrix,
#     164                                 "tocsr", sp.isspmatrix_csr,
# --> 165                                 force_all_finite)
#     166
#     167
#
# ...

# %%
X['ratio']
# Out:
# 0        -0.401199
# 1       -27.986551
# 2        -1.498062
# 3         1.747997
# 4        48.472509
# 5        -6.397002
# 6      -184.396238
# 7       781.230047
# 8       -39.423182
# 9        39.468952
# 10       -7.598939
# 11        1.450119
# 12       46.177036
# 13    15861.192511
# 14        4.074184
# ...
# 5485     306.940619
# 5486    -125.751227
# 5487      -0.257739
# 5488     184.016136
# 5489   -1106.484367
# 5490    8667.505902
# 5491      -0.878449
# 5492     -31.519351
# 5493   -2078.211869
# 5494      -0.014749
# 5495    -361.392148
# 5496      -1.196715
# 5497      18.445365
# 5498    1260.595294
# 5499    -161.429422
# Name: ratio, Length: 5500, dtype: float64

# %%
from sklearn import linear_model
from sklearn import metrics
from sklearn.ensemble import GradientBoostingClassifier
import numpy as np
import pandas as pd
import load_data2 as load_data
import preprocess2 as pre

X_train_A, X_train_B, y_train = load_data.load("train")
X_test_A, X_test_B = load_data.load("test")

X_train_A, X_train_B = pre.common_name(X_train_A,X_train_B)

# %%
A = pre.follow_ratio(X_train_A)

# %%
B = pre.follow_ratio(X_train_B)

# %%
X = A - B

# %%
model = linear_model.LogisticRegression(fit_intercept=False)

# %%
model.fit(X,y_train['Choice'])
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=False,
#           intercept_scaling=1, penalty='l2', random_state=None, tol=0.0001)
